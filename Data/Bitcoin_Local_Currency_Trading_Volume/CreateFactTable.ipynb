# %%
import pandas as pd

# %%
#import the files and save to variable
AED	= 	pd.read_csv(	'/Users/adrianciaff/Documents/GitHub/DSP_AT2/Data/Bitcoin_Local_Currency_Trading_Volume/Raw data/coin-dance-localbitcoins-AED-volume.csv'	)
KZT	= 	pd.read_csv(	'/Users/adrianciaff/Documents/GitHub/DSP_AT2/Data/Bitcoin_Local_Currency_Trading_Volume/Raw data/coin-dance-localbitcoins-KZT-volume.csv'	)
ARS	= 	pd.read_csv(	'/Users/adrianciaff/Documents/GitHub/DSP_AT2/Data/Bitcoin_Local_Currency_Trading_Volume/Raw data/coin-dance-localbitcoins-ARS-volume.csv'	)
MAD	= 	pd.read_csv(	'/Users/adrianciaff/Documents/GitHub/DSP_AT2/Data/Bitcoin_Local_Currency_Trading_Volume/Raw data/coin-dance-localbitcoins-MAD-volume.csv'	)
AUD	= 	pd.read_csv(	'/Users/adrianciaff/Documents/GitHub/DSP_AT2/Data/Bitcoin_Local_Currency_Trading_Volume/Raw data/coin-dance-localbitcoins-AUD-volume.csv'	)
MXN	= 	pd.read_csv(	'/Users/adrianciaff/Documents/GitHub/DSP_AT2/Data/Bitcoin_Local_Currency_Trading_Volume/Raw data/coin-dance-localbitcoins-MXN-volume.csv'	)
BRL	= 	pd.read_csv(	'/Users/adrianciaff/Documents/GitHub/DSP_AT2/Data/Bitcoin_Local_Currency_Trading_Volume/Raw data/coin-dance-localbitcoins-BRL-volume.csv'	)
MYR	=	pd.read_csv(	'/Users/adrianciaff/Documents/GitHub/DSP_AT2/Data/Bitcoin_Local_Currency_Trading_Volume/Raw data/coin-dance-localbitcoins-MYR-volume.csv'	)
CAD	=	pd.read_csv(	'/Users/adrianciaff/Documents/GitHub/DSP_AT2/Data/Bitcoin_Local_Currency_Trading_Volume/Raw data/coin-dance-localbitcoins-CAD-volume.csv'	)
NGN	=	pd.read_csv(	'/Users/adrianciaff/Documents/GitHub/DSP_AT2/Data/Bitcoin_Local_Currency_Trading_Volume/Raw data/coin-dance-localbitcoins-NGN-volume.csv'	)
CHF	=	pd.read_csv(	'/Users/adrianciaff/Documents/GitHub/DSP_AT2/Data/Bitcoin_Local_Currency_Trading_Volume/Raw data/coin-dance-localbitcoins-CHF-volume.csv'	)
NOK	=	pd.read_csv(	'/Users/adrianciaff/Documents/GitHub/DSP_AT2/Data/Bitcoin_Local_Currency_Trading_Volume/Raw data/coin-dance-localbitcoins-NOK-volume.csv'	)
CLP	=	pd.read_csv(	'/Users/adrianciaff/Documents/GitHub/DSP_AT2/Data/Bitcoin_Local_Currency_Trading_Volume/Raw data/coin-dance-localbitcoins-CLP-volume.csv'	)
NZD	=	pd.read_csv(	'/Users/adrianciaff/Documents/GitHub/DSP_AT2/Data/Bitcoin_Local_Currency_Trading_Volume/Raw data/coin-dance-localbitcoins-NZD-volume.csv'	)
CNY	=	pd.read_csv(	'/Users/adrianciaff/Documents/GitHub/DSP_AT2/Data/Bitcoin_Local_Currency_Trading_Volume/Raw data/coin-dance-localbitcoins-CNY-volume.csv'	)
PEN	=	pd.read_csv(	'/Users/adrianciaff/Documents/GitHub/DSP_AT2/Data/Bitcoin_Local_Currency_Trading_Volume/Raw data/coin-dance-localbitcoins-PEN-volume.csv'	)
COP	=	pd.read_csv(	'/Users/adrianciaff/Documents/GitHub/DSP_AT2/Data/Bitcoin_Local_Currency_Trading_Volume/Raw data/coin-dance-localbitcoins-COP-volume.csv'	)
PHP	=	pd.read_csv(	'/Users/adrianciaff/Documents/GitHub/DSP_AT2/Data/Bitcoin_Local_Currency_Trading_Volume/Raw data/coin-dance-localbitcoins-PHP-volume.csv'	)
CZK	=	pd.read_csv(	'/Users/adrianciaff/Documents/GitHub/DSP_AT2/Data/Bitcoin_Local_Currency_Trading_Volume/Raw data/coin-dance-localbitcoins-CZK-volume.csv'	)
PKR	=	pd.read_csv(	'/Users/adrianciaff/Documents/GitHub/DSP_AT2/Data/Bitcoin_Local_Currency_Trading_Volume/Raw data/coin-dance-localbitcoins-PKR-volume.csv'	)
DKK	=	pd.read_csv(	'/Users/adrianciaff/Documents/GitHub/DSP_AT2/Data/Bitcoin_Local_Currency_Trading_Volume/Raw data/coin-dance-localbitcoins-DKK-volume.csv'	)
PLN	=	pd.read_csv(	'/Users/adrianciaff/Documents/GitHub/DSP_AT2/Data/Bitcoin_Local_Currency_Trading_Volume/Raw data/coin-dance-localbitcoins-PLN-volume.csv'	)
DOP	=	pd.read_csv(	'/Users/adrianciaff/Documents/GitHub/DSP_AT2/Data/Bitcoin_Local_Currency_Trading_Volume/Raw data/coin-dance-localbitcoins-DOP-volume.csv'	)
RON	=	pd.read_csv(	'/Users/adrianciaff/Documents/GitHub/DSP_AT2/Data/Bitcoin_Local_Currency_Trading_Volume/Raw data/coin-dance-localbitcoins-RON-volume.csv'	)
EGP	=	pd.read_csv(	'/Users/adrianciaff/Documents/GitHub/DSP_AT2/Data/Bitcoin_Local_Currency_Trading_Volume/Raw data/coin-dance-localbitcoins-EGP-volume.csv'	)
RUB	=	pd.read_csv(	'/Users/adrianciaff/Documents/GitHub/DSP_AT2/Data/Bitcoin_Local_Currency_Trading_Volume/Raw data/coin-dance-localbitcoins-RUB-volume.csv'	)
EUR	=	pd.read_csv(	'/Users/adrianciaff/Documents/GitHub/DSP_AT2/Data/Bitcoin_Local_Currency_Trading_Volume/Raw data/coin-dance-localbitcoins-EUR-volume.csv'	)
SAR	=	pd.read_csv(	'/Users/adrianciaff/Documents/GitHub/DSP_AT2/Data/Bitcoin_Local_Currency_Trading_Volume/Raw data/coin-dance-localbitcoins-SAR-volume.csv'	)
GBP	=	pd.read_csv(	'/Users/adrianciaff/Documents/GitHub/DSP_AT2/Data/Bitcoin_Local_Currency_Trading_Volume/Raw data/coin-dance-localbitcoins-GBP-volume.csv'	)
SEK	=	pd.read_csv(	'/Users/adrianciaff/Documents/GitHub/DSP_AT2/Data/Bitcoin_Local_Currency_Trading_Volume/Raw data/coin-dance-localbitcoins-SEK-volume.csv'	)
HKD	=	pd.read_csv(	'/Users/adrianciaff/Documents/GitHub/DSP_AT2/Data/Bitcoin_Local_Currency_Trading_Volume/Raw data/coin-dance-localbitcoins-HKD-volume.csv'	)
SGD	=	pd.read_csv(	'/Users/adrianciaff/Documents/GitHub/DSP_AT2/Data/Bitcoin_Local_Currency_Trading_Volume/Raw data/coin-dance-localbitcoins-SGD-volume.csv'	)
HRK	=	pd.read_csv(	'/Users/adrianciaff/Documents/GitHub/DSP_AT2/Data/Bitcoin_Local_Currency_Trading_Volume/Raw data/coin-dance-localbitcoins-HRK-volume.csv'	)
THB	=	pd.read_csv(	'/Users/adrianciaff/Documents/GitHub/DSP_AT2/Data/Bitcoin_Local_Currency_Trading_Volume/Raw data/coin-dance-localbitcoins-THB-volume.csv'	)
HUF	=	pd.read_csv(	'/Users/adrianciaff/Documents/GitHub/DSP_AT2/Data/Bitcoin_Local_Currency_Trading_Volume/Raw data/coin-dance-localbitcoins-HUF-volume.csv'	)
TRY	=	pd.read_csv(	'/Users/adrianciaff/Documents/GitHub/DSP_AT2/Data/Bitcoin_Local_Currency_Trading_Volume/Raw data/coin-dance-localbitcoins-TRY-volume.csv'	)
IDR	=	pd.read_csv(	'/Users/adrianciaff/Documents/GitHub/DSP_AT2/Data/Bitcoin_Local_Currency_Trading_Volume/Raw data/coin-dance-localbitcoins-IDR-volume.csv'	)
TZS	=	pd.read_csv(	'/Users/adrianciaff/Documents/GitHub/DSP_AT2/Data/Bitcoin_Local_Currency_Trading_Volume/Raw data/coin-dance-localbitcoins-TZS-volume.csv'	)
INR	=	pd.read_csv(	'/Users/adrianciaff/Documents/GitHub/DSP_AT2/Data/Bitcoin_Local_Currency_Trading_Volume/Raw data/coin-dance-localbitcoins-INR-volume.csv'	)
UAH	=	pd.read_csv(	'/Users/adrianciaff/Documents/GitHub/DSP_AT2/Data/Bitcoin_Local_Currency_Trading_Volume/Raw data/coin-dance-localbitcoins-UAH-volume.csv'	)
IRR	=	pd.read_csv(	'/Users/adrianciaff/Documents/GitHub/DSP_AT2/Data/Bitcoin_Local_Currency_Trading_Volume/Raw data/coin-dance-localbitcoins-IRR-volume.csv'	)
USD	=	pd.read_csv(	'/Users/adrianciaff/Documents/GitHub/DSP_AT2/Data/Bitcoin_Local_Currency_Trading_Volume/Raw data/coin-dance-localbitcoins-USD-volume.csv'	)
JPY	=	pd.read_csv(	'/Users/adrianciaff/Documents/GitHub/DSP_AT2/Data/Bitcoin_Local_Currency_Trading_Volume/Raw data/coin-dance-localbitcoins-JPY-volume.csv'	)
VES	=	pd.read_csv(	'/Users/adrianciaff/Documents/GitHub/DSP_AT2/Data/Bitcoin_Local_Currency_Trading_Volume/Raw data/coin-dance-localbitcoins-VES-volume.csv'	)
KES	=	pd.read_csv(	'/Users/adrianciaff/Documents/GitHub/DSP_AT2/Data/Bitcoin_Local_Currency_Trading_Volume/Raw data/coin-dance-localbitcoins-KES-volume.csv'	)
VND	=	pd.read_csv(	'/Users/adrianciaff/Documents/GitHub/DSP_AT2/Data/Bitcoin_Local_Currency_Trading_Volume/Raw data/coin-dance-localbitcoins-VND-volume.csv'	)
KRW	=	pd.read_csv(	'/Users/adrianciaff/Documents/GitHub/DSP_AT2/Data/Bitcoin_Local_Currency_Trading_Volume/Raw data/coin-dance-localbitcoins-KRW-volume.csv'	)
ZAR	=	pd.read_csv(	'/Users/adrianciaff/Documents/GitHub/DSP_AT2/Data/Bitcoin_Local_Currency_Trading_Volume/Raw data/coin-dance-localbitcoins-ZAR-volume.csv'	)

# %%
#add a column for the currency dimension code
AED	['Currency_Code']	=	'AED'
KZT	['Currency_Code']	=	'KZT'
ARS	['Currency_Code']	=	'ARS'
MAD	['Currency_Code']	=	'MAD'
AUD	['Currency_Code']	=	'AUD'
MXN	['Currency_Code']	=	'MXN'
BRL	['Currency_Code']	=	'BRL'
MYR	['Currency_Code']	=	'MYR'
CAD	['Currency_Code']	=	'CAD'
NGN	['Currency_Code']	=	'NGN'
CHF	['Currency_Code']	=	'CHF'
NOK	['Currency_Code']	=	'NOK'
CLP	['Currency_Code']	=	'CLP'
NZD	['Currency_Code']	=	'NZD'
CNY	['Currency_Code']	=	'CNY'
PEN	['Currency_Code']	=	'PEN'
COP	['Currency_Code']	=	'COP'
PHP	['Currency_Code']	=	'PHP'
CZK	['Currency_Code']	=	'CZK'
PKR	['Currency_Code']	=	'PKR'
DKK	['Currency_Code']	=	'DKK'
PLN	['Currency_Code']	=	'PLN'
DOP	['Currency_Code']	=	'DOP'
RON	['Currency_Code']	=	'RON'
EGP	['Currency_Code']	=	'EGP'
RUB	['Currency_Code']	=	'RUB'
EUR	['Currency_Code']	=	'EUR'
SAR	['Currency_Code']	=	'SAR'
GBP	['Currency_Code']	=	'GBP'
SEK	['Currency_Code']	=	'SEK'
HKD	['Currency_Code']	=	'HKD'
SGD	['Currency_Code']	=	'SGD'
HRK	['Currency_Code']	=	'HRK'
THB	['Currency_Code']	=	'THB'
HUF	['Currency_Code']	=	'HUF'
TRY	['Currency_Code']	=	'TRY'
IDR	['Currency_Code']	=	'IDR'
TZS	['Currency_Code']	=	'TZS'
INR	['Currency_Code']	=	'INR'
UAH	['Currency_Code']	=	'UAH'
IRR	['Currency_Code']	=	'IRR'
USD	['Currency_Code']	=	'USD'
JPY	['Currency_Code']	=	'JPY'
VES	['Currency_Code']	=	'VES'
KES	['Currency_Code']	=	'KES'
VND	['Currency_Code']	=	'VND'
KRW	['Currency_Code']	=	'KRW'
ZAR	['Currency_Code']	=	'ZAR'

# %%
#combine the dataframes vertically
Fact_Bitcoin_Local_Currency = pd.concat([
    AED,
    KZT,
    ARS,
    MAD,
    AUD,
    MXN,
    BRL,
    MYR,
    CAD,
    NGN,
    CHF,
    NOK,
    CLP,
    NZD,
    CNY,
    PEN,
    COP,
    PHP,
    CZK,
    PKR,
    DKK,
    PLN,
    DOP,
    RON,
    EGP,
    RUB,
    EUR,
    SAR,
    GBP,
    SEK,
    HKD,
    SGD,
    HRK,
    THB,
    HUF,
    TRY,
    IDR,
    TZS,
    INR,
    UAH,
    IRR,
    USD,
    JPY,
    VES,
    KES,
    VND,
    KRW,
    ZAR 
])

# %%
#write to csv
Fact_Bitcoin_Local_Currency.to_csv('/Users/adrianciaff/Documents/GitHub/DSP_AT2/Data/Bitcoin_Local_Currency_Trading_Volume/Fact_Trading_Volume_Local_Currency.csv')
