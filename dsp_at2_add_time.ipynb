# %%
#Assignment Task 2

#load main packages
import numpy as np
import pandas as pd
import matplotlib as plt
import matplotlib.pyplot as plt

#creating time dimensions to files
#1
active_addresses = pd.read_csv("active-addresses.csv")
print(active_addresses.t.dtype)

#added date
active_addresses = active_addresses.assign(date=pd.Series(active_addresses['t'].astype('datetime64[ns]')))

#added day number
active_addresses = active_addresses.assign(day=pd.Series(active_addresses['date'].dt.day))

#added week day
active_addresses = active_addresses.assign(weekday=pd.Series(active_addresses['date'].dt.weekday))
#0 = Monday, 1 = Tuesday ... 6 = Sunday

#added week number
active_addresses = active_addresses.assign(weeknum=pd.Series(active_addresses['date'].dt.week))

#added month
active_addresses = active_addresses.assign(month=pd.Series(active_addresses['date'].dt.month))

#added year
active_addresses = active_addresses.assign(year=pd.Series(active_addresses['date'].dt.year))

#active_addresses.head(20)


#2
addresses_balance = pd.read_csv("addresses-with-balance-≥-0-01.csv")

#added date
addresses_balance = addresses_balance.assign(date=pd.Series(addresses_balance['t'].astype('datetime64[ns]')))
#added day number
addresses_balance = addresses_balance.assign(day=pd.Series(addresses_balance['date'].dt.day))
#added week day
addresses_balance = addresses_balance.assign(weekday=pd.Series(addresses_balance['date'].dt.weekday))
#0 = Monday, 1 = Tuesday ... 6 = Sunday
#added week number
addresses_balance = addresses_balance.assign(weeknum=pd.Series(addresses_balance['date'].dt.week))
#added month
addresses_balance = addresses_balance.assign(month=pd.Series(addresses_balance['date'].dt.month))
#added year
addresses_balance = addresses_balance.assign(year=pd.Series(addresses_balance['date'].dt.year))

#addresses_balance.head(20)

#3
net_flow_vol = pd.read_csv("exchange-net-flow-volume.csv")

#added date
net_flow_vol = net_flow_vol.assign(date=pd.Series(net_flow_vol['t'].astype('datetime64[ns]')))
#added day number
net_flow_vol = net_flow_vol.assign(day=pd.Series(net_flow_vol['date'].dt.day))
#added week day
net_flow_vol = net_flow_vol.assign(weekday=pd.Series(net_flow_vol['date'].dt.weekday))
#0 = Monday, 1 = Tuesday ... 6 = Sunday
#added week number
net_flow_vol = net_flow_vol.assign(weeknum=pd.Series(net_flow_vol['date'].dt.week))
#added month
net_flow_vol = net_flow_vol.assign(month=pd.Series(net_flow_vol['date'].dt.month))
#added year
net_flow_vol = net_flow_vol.assign(year=pd.Series(net_flow_vol['date'].dt.year))

#net_flow_vol.head(20)


#4
hash_rate = pd.read_csv("hash-rate.csv")

#added date
hash_rate = hash_rate.assign(date=pd.Series(hash_rate['t'].astype('datetime64[ns]')))
#added day number
hash_rate = hash_rate.assign(day=pd.Series(hash_rate['date'].dt.day))
#added week day
hash_rate = hash_rate.assign(weekday=pd.Series(hash_rate['date'].dt.weekday))
#0 = Monday, 1 = Tuesday ... 6 = Sunday
#added week number
hash_rate = hash_rate.assign(weeknum=pd.Series(hash_rate['date'].dt.week))
#added month
hash_rate = hash_rate.assign(month=pd.Series(hash_rate['date'].dt.month))
#added year
hash_rate = hash_rate.assign(year=pd.Series(hash_rate['date'].dt.year))

#hash_rate.head(20)


#5
market_cap = pd.read_csv("market-cap.csv")

#added date
market_cap = market_cap.assign(date=pd.Series(market_cap['t'].astype('datetime64[ns]')))
#added day number
market_cap = market_cap.assign(day=pd.Series(market_cap['date'].dt.day))
#added week day
market_cap = market_cap.assign(weekday=pd.Series(market_cap['date'].dt.weekday))
#0 = Monday, 1 = Tuesday ... 6 = Sunday
#added week number
market_cap = market_cap.assign(weeknum=pd.Series(market_cap['date'].dt.week))
#added month
market_cap = market_cap.assign(month=pd.Series(market_cap['date'].dt.month))
#added year
market_cap = market_cap.assign(year=pd.Series(market_cap['date'].dt.year))

market_cap.head(20)


#6
new_addresses = pd.read_csv("new-addresses.csv")

#added date
new_addresses = new_addresses.assign(date=pd.Series(new_addresses['t'].astype('datetime64[ns]')))
#added day number
new_addresses = new_addresses.assign(day=pd.Series(new_addresses['date'].dt.day))
#added week day
new_addresses = new_addresses.assign(weekday=pd.Series(new_addresses['date'].dt.weekday))
#0 = Monday, 1 = Tuesday ... 6 = Sunday
#added week number
new_addresses = new_addresses.assign(weeknum=pd.Series(new_addresses['date'].dt.week))
#added month
new_addresses = new_addresses.assign(month=pd.Series(new_addresses['date'].dt.month))
#added year
new_addresses = new_addresses.assign(year=pd.Series(new_addresses['date'].dt.year))

#new_addresses.head(20)



#7
price = pd.read_csv("price.csv")

#added date
price = price.assign(date=pd.Series(price['t'].astype('datetime64[ns]')))
#added day number
price = price.assign(day=pd.Series(price['date'].dt.day))
#added week day
price = price.assign(weekday=pd.Series(price['date'].dt.weekday))
#0 = Monday, 1 = Tuesday ... 6 = Sunday
#added week number
price = price.assign(weeknum=pd.Series(price['date'].dt.week))
#added month
price = price.assign(month=pd.Series(price['date'].dt.month))
#added year
price = price.assign(year=pd.Series(price['date'].dt.year))

#price.head(20)


#8
transaction_count = pd.read_csv("transaction-count.csv")

#added date
transaction_count = transaction_count.assign(date=pd.Series(transaction_count['t'].astype('datetime64[ns]')))
#added day number
transaction_count = transaction_count.assign(day=pd.Series(transaction_count['date'].dt.day))
#added week day
transaction_count = transaction_count.assign(weekday=pd.Series(transaction_count['date'].dt.weekday))
#0 = Monday, 1 = Tuesday ... 6 = Sunday
#added week number
transaction_count = transaction_count.assign(weeknum=pd.Series(transaction_count['date'].dt.week))
#added month
transaction_count = transaction_count.assign(month=pd.Series(transaction_count['date'].dt.month))
#added year
transaction_count = transaction_count.assign(year=pd.Series(transaction_count['date'].dt.year))

#transaction_count.head(20)


#9
transaction_rate = pd.read_csv("transaction-rate.csv")

#added date
transaction_rate = transaction_rate.assign(date=pd.Series(transaction_rate['t'].astype('datetime64[ns]')))
#added day number
transaction_rate = transaction_rate.assign(day=pd.Series(transaction_rate['date'].dt.day))
#added week day
transaction_rate = transaction_rate.assign(weekday=pd.Series(transaction_rate['date'].dt.weekday))
#0 = Monday, 1 = Tuesday ... 6 = Sunday
#added week number
transaction_rate = transaction_rate.assign(weeknum=pd.Series(transaction_rate['date'].dt.week))
#added month
transaction_rate = transaction_rate.assign(month=pd.Series(transaction_rate['date'].dt.month))
#added year
transaction_rate = transaction_rate.assign(year=pd.Series(transaction_rate['date'].dt.year))

#transaction_rate.head(20)


#10
transfer_vol_ttl = pd.read_csv("transfer-volume-total.csv")

#added date
transfer_vol_ttl = transfer_vol_ttl.assign(date=pd.Series(transfer_vol_ttl['t'].astype('datetime64[ns]')))
#added day number
transfer_vol_ttl = transfer_vol_ttl.assign(day=pd.Series(transfer_vol_ttl['date'].dt.day))
#added week day
transfer_vol_ttl = transfer_vol_ttl.assign(weekday=pd.Series(transfer_vol_ttl['date'].dt.weekday))
#0 = Monday, 1 = Tuesday ... 6 = Sunday
#added week number
transfer_vol_ttl = transfer_vol_ttl.assign(weeknum=pd.Series(transfer_vol_ttl['date'].dt.week))
#added month
transfer_vol_ttl = transfer_vol_ttl.assign(month=pd.Series(transfer_vol_ttl['date'].dt.month))
#added year
transfer_vol_ttl = transfer_vol_ttl.assign(year=pd.Series(transfer_vol_ttl['date'].dt.year))

transfer_vol_ttl.head(20)
transfer_vol_ttl.to_csv("transfer_vol_ttl.csv", index=False)
# Out:
# object
